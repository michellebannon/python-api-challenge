# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as stats

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Start of Data Retrieval ")
print("-----------------------------")
index_counter = 0
set_counter = 1

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
url = f"{url}appid={weather_api_key}&units={units}&q="

# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(url + city).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} | {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Start of Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | asau
# Processing Record 2 of Set 1 | talcahuano
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | thinadhoo
# Processing Record 6 of Set 1 | gazli
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | ambilobe
# Processing Record 9 of Set 1 | sobolevo
# Processing Record 10 of Set 1 | san patricio
# City not found. Skipping...
# Processing Record 11 of Set 1 | zyryanka
# Processing Record 12 of Set 1 | quatre cocos
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | geraldton
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | broome
# Processing Record 17 of Set 1 | ryotsu
# Processing Record 18 of Set 1 | lompoc
# Processing Record 19 of Set 1 | terrace
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | sao miguel dos campos
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | mayenne
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | hargeysa
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | wellington
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | sumter
# Processing Record 34 of Set 1 | upernavik
# Processing Record 35 of Set 1 | klaksvik
# Processing Record 36 of Set 1 | isangel
# Processing Record 37 of Set 1 | victoria
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | sorland
# Processing Record 40 of Set 1 | mecca
# Processing Record 41 of Set 1 | vila do maio
# Processing Record 42 of Set 1 | mount isa
# Processing Record 43 of Set 1 | sitka
# Processing Record 44 of Set 1 | mahbubnagar
# Processing Record 45 of Set 1 | qaanaaq
# City not found. Skipping...
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | conakry
# Processing Record 48 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 49 of Set 1 | evensk
# Processing Record 50 of Set 1 | puerto baquerizo moreno
# Processing Record 0 of Set 2 | olinda
# Processing Record 1 of Set 2 | kieta
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | abalak
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | nabire
# Processing Record 6 of Set 2 | cairns
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | belyy yar
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | cherskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | clyde river
# Processing Record 13 of Set 2 | jamestown
# City not found. Skipping...
# Processing Record 14 of Set 2 | nizwa
# Processing Record 15 of Set 2 | pevek
# Processing Record 16 of Set 2 | labuhan
# Processing Record 17 of Set 2 | lagoa
# Processing Record 18 of Set 2 | upata
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | san cristobal
# Processing Record 21 of Set 2 | cravo norte
# Processing Record 22 of Set 2 | norman wells
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | osypenko
# Processing Record 25 of Set 2 | umm lajj
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | faanui
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | souillac
# Processing Record 30 of Set 2 | ampanihy
# Processing Record 31 of Set 2 | siocon
# Processing Record 32 of Set 2 | pyshma
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | anadyr
# Processing Record 35 of Set 2 | puerto madero
# Processing Record 36 of Set 2 | harij
# Processing Record 37 of Set 2 | morgan city
# City not found. Skipping...
# Processing Record 38 of Set 2 | namatanai
# City not found. Skipping...
# Processing Record 39 of Set 2 | rorvik
# Processing Record 40 of Set 2 | bathsheba
# Processing Record 41 of Set 2 | kimbe
# Processing Record 42 of Set 2 | effingham
# Processing Record 43 of Set 2 | aasiaat
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | torbay
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | bonavista
# Processing Record 48 of Set 2 | saint anthony
# Processing Record 49 of Set 2 | hobyo
# Processing Record 50 of Set 2 | iqaluit
# Processing Record 0 of Set 3 | dehloran
# Processing Record 1 of Set 3 | kununurra
# Processing Record 2 of Set 3 | maragogi
# Processing Record 3 of Set 3 | lavrentiya
# Processing Record 4 of Set 3 | povenets
# Processing Record 5 of Set 3 | tual
# Processing Record 6 of Set 3 | mogok
# Processing Record 7 of Set 3 | zarubino
# Processing Record 8 of Set 3 | perleberg
# Processing Record 9 of Set 3 | roald
# City not found. Skipping...
# Processing Record 10 of Set 3 | cascais
# City not found. Skipping...
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | otawara
# Processing Record 13 of Set 3 | gizo
# Processing Record 14 of Set 3 | padang
# Processing Record 15 of Set 3 | kruisfontein
# Processing Record 16 of Set 3 | hermanus
# Processing Record 17 of Set 3 | umea
# Processing Record 18 of Set 3 | vallenar
# Processing Record 19 of Set 3 | paralia
# Processing Record 20 of Set 3 | portland
# Processing Record 21 of Set 3 | bone
# Processing Record 22 of Set 3 | leningradskiy
# Processing Record 23 of Set 3 | sao joao da barra
# Processing Record 24 of Set 3 | dikson
# Processing Record 25 of Set 3 | butaritari
# Processing Record 26 of Set 3 | puerto ayacucho
# Processing Record 27 of Set 3 | galle
# Processing Record 28 of Set 3 | port elizabeth
# Processing Record 29 of Set 3 | haines junction
# Processing Record 30 of Set 3 | port macquarie
# Processing Record 31 of Set 3 | sao joao del rei
# Processing Record 32 of Set 3 | pisco
# Processing Record 33 of Set 3 | niono
# Processing Record 34 of Set 3 | lichuan
# City not found. Skipping...
# Processing Record 35 of Set 3 | airai
# Processing Record 36 of Set 3 | kahului
# Processing Record 37 of Set 3 | la macarena
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | hobart
# Processing Record 40 of Set 3 | new norfolk
# Processing Record 41 of Set 3 | hay river
# Processing Record 42 of Set 3 | goundam
# Processing Record 43 of Set 3 | mandalgovi
# Processing Record 44 of Set 3 | batemans bay
# Processing Record 45 of Set 3 | lata
# Processing Record 46 of Set 3 | tutoia
# Processing Record 47 of Set 3 | hervey bay
# Processing Record 48 of Set 3 | fortuna
# Processing Record 49 of Set 3 | ostroleka
# Processing Record 50 of Set 3 | mount gambier
# Processing Record 0 of Set 4 | skibbereen
# Processing Record 1 of Set 4 | walvis bay
# Processing Record 2 of Set 4 | berlevag
# Processing Record 3 of Set 4 | ahipara
# Processing Record 4 of Set 4 | yar-sale
# City not found. Skipping...
# Processing Record 5 of Set 4 | shimoda
# Processing Record 6 of Set 4 | fort morgan
# Processing Record 7 of Set 4 | kapaa
# Processing Record 8 of Set 4 | samarai
# Processing Record 9 of Set 4 | esperance
# Processing Record 10 of Set 4 | ruteng
# Processing Record 11 of Set 4 | khatanga
# Processing Record 12 of Set 4 | najran
# Processing Record 13 of Set 4 | yining
# Processing Record 14 of Set 4 | bengkulu
# Processing Record 15 of Set 4 | makurdi
# Processing Record 16 of Set 4 | kandalaksha
# Processing Record 17 of Set 4 | poltava
# Processing Record 18 of Set 4 | eyl
# Processing Record 19 of Set 4 | chokurdakh
# Processing Record 20 of Set 4 | jalu
# Processing Record 21 of Set 4 | villazon
# Processing Record 22 of Set 4 | khrebtovaya
# Processing Record 23 of Set 4 | mabaruma
# Processing Record 24 of Set 4 | praia da vitoria
# Processing Record 25 of Set 4 | troitskoye
# Processing Record 26 of Set 4 | camacha
# Processing Record 27 of Set 4 | xining
# Processing Record 28 of Set 4 | alyangula
# Processing Record 29 of Set 4 | clarence town
# Processing Record 30 of Set 4 | cabo san lucas
# Processing Record 31 of Set 4 | hasaki
# Processing Record 32 of Set 4 | algiers
# Processing Record 33 of Set 4 | saskylakh
# Processing Record 34 of Set 4 | brae
# Processing Record 35 of Set 4 | sioux lookout
# Processing Record 36 of Set 4 | mezen
# Processing Record 37 of Set 4 | conselheiro pena
# Processing Record 38 of Set 4 | ossora
# Processing Record 39 of Set 4 | vila franca do campo
# City not found. Skipping...
# Processing Record 40 of Set 4 | bambous virieux
# Processing Record 41 of Set 4 | los llanos de aridane
# Processing Record 42 of Set 4 | muriwai beach
# City not found. Skipping...
# Processing Record 43 of Set 4 | bongaree
# City not found. Skipping...
# Processing Record 44 of Set 4 | fort-shevchenko
# Processing Record 45 of Set 4 | dwarka
# Processing Record 46 of Set 4 | akcaabat
# Processing Record 47 of Set 4 | cidreira
# Processing Record 48 of Set 4 | hamilton
# Processing Record 49 of Set 4 | primorsk
# Processing Record 50 of Set 4 | ixtapa
# Processing Record 0 of Set 5 | hilo
# City not found. Skipping...
# Processing Record 1 of Set 5 | miyako
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 5 | arraial do cabo
# Processing Record 3 of Set 5 | necochea
# Processing Record 4 of Set 5 | sur
# Processing Record 5 of Set 5 | bowmore
# Processing Record 6 of Set 5 | vila velha
# Processing Record 7 of Set 5 | parkes
# Processing Record 8 of Set 5 | pangai
# Processing Record 9 of Set 5 | kailua
# Processing Record 10 of Set 5 | matagami
# Processing Record 11 of Set 5 | phu ly
# Processing Record 12 of Set 5 | mexico
# Processing Record 13 of Set 5 | sangar
# Processing Record 14 of Set 5 | freeport
# Processing Record 15 of Set 5 | ayagoz
# Processing Record 16 of Set 5 | puerto escondido
# Processing Record 17 of Set 5 | alekseyevka
# City not found. Skipping...
# Processing Record 18 of Set 5 | ankang
# Processing Record 19 of Set 5 | sao filipe
# Processing Record 20 of Set 5 | nicoya
# Processing Record 21 of Set 5 | manta
# Processing Record 22 of Set 5 | saint george
# Processing Record 23 of Set 5 | olafsvik
# City not found. Skipping...
# Processing Record 24 of Set 5 | taoudenni
# Processing Record 25 of Set 5 | camrose
# Processing Record 26 of Set 5 | andenes
# Processing Record 27 of Set 5 | asyut
# Processing Record 28 of Set 5 | ojinaga
# Processing Record 29 of Set 5 | jiangyou
# Processing Record 30 of Set 5 | dingle
# Processing Record 31 of Set 5 | pacifica
# Processing Record 32 of Set 5 | kantang
# Processing Record 33 of Set 5 | white rock
# Processing Record 34 of Set 5 | leninsk-kuznetskiy
# Processing Record 35 of Set 5 | shache
# Processing Record 36 of Set 5 | volchikha
# Processing Record 37 of Set 5 | davenda
# Processing Record 38 of Set 5 | araouane
# Processing Record 39 of Set 5 | muros
# Processing Record 40 of Set 5 | venado tuerto
# Processing Record 41 of Set 5 | stornoway
# Processing Record 42 of Set 5 | turukhansk
# Processing Record 43 of Set 5 | ratangarh
# Processing Record 44 of Set 5 | alice springs
# Processing Record 45 of Set 5 | te anau
# Processing Record 46 of Set 5 | aktau
# Processing Record 47 of Set 5 | bayanday
# Processing Record 48 of Set 5 | aksarka
# Processing Record 49 of Set 5 | sakakah
# Processing Record 50 of Set 5 | ancud
# Processing Record 0 of Set 6 | okhotsk
# Processing Record 1 of Set 6 | tuatapere
# Processing Record 2 of Set 6 | thaton
# Processing Record 3 of Set 6 | nehe
# Processing Record 4 of Set 6 | pemangkat
# Processing Record 5 of Set 6 | ahuimanu
# Processing Record 6 of Set 6 | carnarvon
# Processing Record 7 of Set 6 | dongsheng
# Processing Record 8 of Set 6 | carauari
# Processing Record 9 of Set 6 | sagua la grande
# Processing Record 10 of Set 6 | ilulissat
# Processing Record 11 of Set 6 | amazar
# Processing Record 12 of Set 6 | saldanha
# Processing Record 13 of Set 6 | newport
# Processing Record 14 of Set 6 | venice
# Processing Record 15 of Set 6 | aklavik
# Processing Record 16 of Set 6 | madingou
# Processing Record 17 of Set 6 | luwuk
# Processing Record 18 of Set 6 | jiamusi
# Processing Record 19 of Set 6 | severodvinsk
# Processing Record 20 of Set 6 | morondava
# Processing Record 21 of Set 6 | belyy
# Processing Record 22 of Set 6 | tasiilaq
# Processing Record 23 of Set 6 | strezhevoy
# Processing Record 24 of Set 6 | caraz
# Processing Record 25 of Set 6 | armizonskoye
# Processing Record 26 of Set 6 | aligudarz
# Processing Record 27 of Set 6 | baker city
# Processing Record 28 of Set 6 | vanimo
# Processing Record 29 of Set 6 | hithadhoo
# City not found. Skipping...
# Processing Record 30 of Set 6 | winnetka
# City not found. Skipping...
# Processing Record 31 of Set 6 | izumo
# Processing Record 32 of Set 6 | alugan
# Processing Record 33 of Set 6 | moose factory
# Processing Record 34 of Set 6 | kyren
# Processing Record 35 of Set 6 | viedma
# Processing Record 36 of Set 6 | laguna
# Processing Record 37 of Set 6 | poum
# City not found. Skipping...
# Processing Record 38 of Set 6 | la ronge
# Processing Record 39 of Set 6 | rio grande
# Processing Record 40 of Set 6 | fort nelson
# City not found. Skipping...
# Processing Record 41 of Set 6 | provideniya
# City not found. Skipping...
# Processing Record 42 of Set 6 | longyearbyen
# Processing Record 43 of Set 6 | dhidhdhoo
# Processing Record 44 of Set 6 | pitimbu
# Processing Record 45 of Set 6 | igarka
# Processing Record 46 of Set 6 | mazatlan
# City not found. Skipping...
# Processing Record 47 of Set 6 | antofagasta
# Processing Record 48 of Set 6 | mogadishu
# Processing Record 49 of Set 6 | bogorodskoye
# Processing Record 50 of Set 6 | ponta delgada
# Processing Record 0 of Set 7 | vanavara
# Processing Record 1 of Set 7 | barkot
# Processing Record 2 of Set 7 | constitucion
# Processing Record 3 of Set 7 | cayenne
# Processing Record 4 of Set 7 | abonnema
# Processing Record 5 of Set 7 | huambo
# Processing Record 6 of Set 7 | goderich
# Processing Record 7 of Set 7 | belem de sao francisco
# City not found. Skipping...
# Processing Record 8 of Set 7 | nanortalik
# Processing Record 9 of Set 7 | marsabit
# Processing Record 10 of Set 7 | narsaq
# Processing Record 11 of Set 7 | kavieng
# Processing Record 12 of Set 7 | naze
# Processing Record 13 of Set 7 | chaumont
# Processing Record 14 of Set 7 | salalah
# Processing Record 15 of Set 7 | homer
# Processing Record 16 of Set 7 | san quintin
# Processing Record 17 of Set 7 | jinchang
# Processing Record 18 of Set 7 | tete
# Processing Record 19 of Set 7 | jumla
# Processing Record 20 of Set 7 | truckee
# City not found. Skipping...
# Processing Record 21 of Set 7 | touros
# Processing Record 22 of Set 7 | lethem
# Processing Record 23 of Set 7 | havre-saint-pierre
# Processing Record 24 of Set 7 | luganville
# Processing Record 25 of Set 7 | ibra
# Processing Record 26 of Set 7 | rocha
# Processing Record 27 of Set 7 | polczyn-zdroj
# Processing Record 28 of Set 7 | pierre
# Processing Record 29 of Set 7 | kavaratti
# Processing Record 30 of Set 7 | luena
# Processing Record 31 of Set 7 | cukai
# Processing Record 32 of Set 7 | hovd
# Processing Record 33 of Set 7 | ponta do sol
# Processing Record 34 of Set 7 | boldumsaz
# Processing Record 35 of Set 7 | tshane
# Processing Record 36 of Set 7 | berdigestyakh
# Processing Record 37 of Set 7 | fairbanks
# Processing Record 38 of Set 7 | leogane
# Processing Record 39 of Set 7 | boralday
# Processing Record 40 of Set 7 | asekeyevo
# Processing Record 41 of Set 7 | holme
# City not found. Skipping...
# Processing Record 42 of Set 7 | baykit
# Processing Record 43 of Set 7 | agropoli
# Processing Record 44 of Set 7 | boa vista
# Processing Record 45 of Set 7 | codrington
# Processing Record 46 of Set 7 | namtsy
# Processing Record 47 of Set 7 | severo-kurilsk
# Processing Record 48 of Set 7 | nova borova
# Processing Record 49 of Set 7 | sechura
# Processing Record 50 of Set 7 | terney
# Processing Record 0 of Set 8 | faya
# Processing Record 1 of Set 8 | cuauhtemoc
# Processing Record 2 of Set 8 | bowen
# City not found. Skipping...
# Processing Record 3 of Set 8 | kuvandyk
# Processing Record 4 of Set 8 | opuwo
# Processing Record 5 of Set 8 | pimentel
# City not found. Skipping...
# Processing Record 6 of Set 8 | coos bay
# Processing Record 7 of Set 8 | marsh harbour
# Processing Record 8 of Set 8 | urucara
# City not found. Skipping...
# Processing Record 9 of Set 8 | sawakin
# Processing Record 10 of Set 8 | great yarmouth
# Processing Record 11 of Set 8 | forrest city
# Processing Record 12 of Set 8 | lucapa
# Processing Record 13 of Set 8 | nome
# Processing Record 14 of Set 8 | huaihua
# Processing Record 15 of Set 8 | kanniyakumari
# Processing Record 16 of Set 8 | ouesso
# Processing Record 17 of Set 8 | tiksi
# Processing Record 18 of Set 8 | kenai
# Processing Record 19 of Set 8 | sabang
# Processing Record 20 of Set 8 | moroto
# Processing Record 21 of Set 8 | sao felix do xingu
# Processing Record 22 of Set 8 | tatarskaya pishlya
# Processing Record 23 of Set 8 | poquoson
# Processing Record 24 of Set 8 | aransas pass
# Processing Record 25 of Set 8 | biak
# Processing Record 26 of Set 8 | karratha
# Processing Record 27 of Set 8 | barcelos
# Processing Record 28 of Set 8 | shushenskoye
# Processing Record 29 of Set 8 | prainha
# Processing Record 30 of Set 8 | shirokiy
# Processing Record 31 of Set 8 | sept-iles
# Processing Record 32 of Set 8 | port hedland
# Processing Record 33 of Set 8 | panaba
# Processing Record 34 of Set 8 | hambantota
# Processing Record 35 of Set 8 | skjervoy
# Processing Record 36 of Set 8 | bonthe
# Processing Record 37 of Set 8 | namie
# Processing Record 38 of Set 8 | sarkand
# Processing Record 39 of Set 8 | avera
# Processing Record 40 of Set 8 | coihaique
# Processing Record 41 of Set 8 | half moon bay
# Processing Record 42 of Set 8 | coquimbo
# Processing Record 43 of Set 8 | gorodets
# Processing Record 44 of Set 8 | general roca
# Processing Record 45 of Set 8 | vao
# Processing Record 46 of Set 8 | el tigre
# Processing Record 47 of Set 8 | micheweni
# Processing Record 48 of Set 8 | aden
# Processing Record 49 of Set 8 | dunedin
# Processing Record 50 of Set 8 | cabangahan
# Processing Record 0 of Set 9 | beloha
# Processing Record 1 of Set 9 | monterey
# Processing Record 2 of Set 9 | saint-joseph
# Processing Record 3 of Set 9 | port-gentil
# Processing Record 4 of Set 9 | fereydun kenar
# Processing Record 5 of Set 9 | pundaguitan
# Processing Record 6 of Set 9 | ceyhan
# Processing Record 7 of Set 9 | manokwari
# Processing Record 8 of Set 9 | logstor
# Processing Record 9 of Set 9 | grand gaube
# Processing Record 10 of Set 9 | margate
# Processing Record 11 of Set 9 | breves
# Processing Record 12 of Set 9 | pervomayskoye
# Processing Record 13 of Set 9 | paramirim
# Processing Record 14 of Set 9 | juquitiba
# Processing Record 15 of Set 9 | chimbote
# Processing Record 16 of Set 9 | zhigansk
# Processing Record 17 of Set 9 | bartica
# Processing Record 18 of Set 9 | minab
# Processing Record 19 of Set 9 | issia
# Processing Record 20 of Set 9 | port lincoln
# Processing Record 21 of Set 9 | port hardy
# Processing Record 22 of Set 9 | kuznetsk
# Processing Record 23 of Set 9 | chemax
# Processing Record 24 of Set 9 | katsuura
# Processing Record 25 of Set 9 | myitkyina
# Processing Record 26 of Set 9 | grand baie
# Processing Record 27 of Set 9 | saint-francois
# Processing Record 28 of Set 9 | bambanglipuro
# Processing Record 29 of Set 9 | sinnamary
# Processing Record 30 of Set 9 | maningrida
# Processing Record 31 of Set 9 | pag
# Processing Record 32 of Set 9 | riyadh
# Processing Record 33 of Set 9 | bandundu
# City not found. Skipping...
# Processing Record 34 of Set 9 | juneau
# Processing Record 35 of Set 9 | marrakesh
# Processing Record 36 of Set 9 | riga
# Processing Record 37 of Set 9 | srednekolymsk
# Processing Record 38 of Set 9 | funadhoo
# Processing Record 39 of Set 9 | la rochelle
# Processing Record 40 of Set 9 | inhambane
# City not found. Skipping...
# Processing Record 41 of Set 9 | kupang
# Processing Record 42 of Set 9 | yaan
# Processing Record 43 of Set 9 | chara
# Processing Record 44 of Set 9 | balgazyn
# Processing Record 45 of Set 9 | port blair
# Processing Record 46 of Set 9 | la asuncion
# Processing Record 47 of Set 9 | zubtsov
# Processing Record 48 of Set 9 | havelock
# Processing Record 49 of Set 9 | trincomalee
# Processing Record 50 of Set 9 | harlingen
# Processing Record 0 of Set 10 | tsogni
# Processing Record 1 of Set 10 | golfito
# Processing Record 2 of Set 10 | huaraz
# Processing Record 3 of Set 10 | xapuri
# Processing Record 4 of Set 10 | kutum
# Processing Record 5 of Set 10 | molepolole
# Processing Record 6 of Set 10 | cap malheureux
# Processing Record 7 of Set 10 | loa janan
# Processing Record 8 of Set 10 | urubicha
# Processing Record 9 of Set 10 | marzuq
# Processing Record 10 of Set 10 | tondano
# Processing Record 11 of Set 10 | merrill
# Processing Record 12 of Set 10 | mormugao
# City not found. Skipping...
# Processing Record 13 of Set 10 | krasnoselkup
# City not found. Skipping...
# Processing Record 14 of Set 10 | kouroussa
# Processing Record 15 of Set 10 | itarema
# Processing Record 16 of Set 10 | prince george
# Processing Record 17 of Set 10 | beyneu
# Processing Record 18 of Set 10 | lazaro cardenas
# Processing Record 19 of Set 10 | goure
# Processing Record 20 of Set 10 | hofn
# Processing Record 21 of Set 10 | eagle pass
# Processing Record 22 of Set 10 | novoagansk
# Processing Record 23 of Set 10 | una
# Processing Record 24 of Set 10 | kwinana
# Processing Record 25 of Set 10 | maceio
# Processing Record 26 of Set 10 | lorengau
# Processing Record 27 of Set 10 | hushitai
# Processing Record 28 of Set 10 | tilichiki
# Processing Record 29 of Set 10 | kodinsk
# Processing Record 30 of Set 10 | amapa
# Processing Record 31 of Set 10 | karpathos
# Processing Record 32 of Set 10 | taltal
# City not found. Skipping...
# Processing Record 33 of Set 10 | flinders
# Processing Record 34 of Set 10 | at-bashi
# Processing Record 35 of Set 10 | beringovskiy
# Processing Record 36 of Set 10 | mayumba
# Processing Record 37 of Set 10 | labrea
# Processing Record 38 of Set 10 | svetlogorsk
# Processing Record 39 of Set 10 | atasu
# Processing Record 40 of Set 10 | maple creek
# Processing Record 41 of Set 10 | maniitsoq
# Processing Record 42 of Set 10 | puerto madryn
# Processing Record 43 of Set 10 | mehamn
# Processing Record 44 of Set 10 | grindavik
# Processing Record 45 of Set 10 | santo andre
# City not found. Skipping...
# Processing Record 46 of Set 10 | launceston
# Processing Record 47 of Set 10 | piacabucu
# Processing Record 48 of Set 10 | banjar
# Processing Record 49 of Set 10 | puerto del rosario
# Processing Record 50 of Set 10 | colares
# Processing Record 0 of Set 11 | pacific grove
# Processing Record 1 of Set 11 | hualmay
# Processing Record 2 of Set 11 | nouadhibou
# Processing Record 3 of Set 11 | bidor
# Processing Record 4 of Set 11 | macas
# Processing Record 5 of Set 11 | pozo colorado
# Processing Record 6 of Set 11 | teya
# Processing Record 7 of Set 11 | victor harbor
# Processing Record 8 of Set 11 | keffi
# City not found. Skipping...
# Processing Record 9 of Set 11 | talnakh
# Processing Record 10 of Set 11 | tipacoque
# Processing Record 11 of Set 11 | yerbogachen
# Processing Record 12 of Set 11 | lukovetskiy
# Processing Record 13 of Set 11 | kismayo
# Processing Record 14 of Set 11 | jalalpur pirwala
# Processing Record 15 of Set 11 | teahupoo
# Processing Record 16 of Set 11 | calabozo
# Processing Record 17 of Set 11 | paamiut
# Processing Record 18 of Set 11 | lev tolstoy
# Processing Record 19 of Set 11 | warner robins
# City not found. Skipping...
# Processing Record 20 of Set 11 | penzance
# Processing Record 21 of Set 11 | abu dhabi
# Processing Record 22 of Set 11 | basti
# Processing Record 23 of Set 11 | megion
# Processing Record 24 of Set 11 | mana
# Processing Record 25 of Set 11 | zheleznodorozhnyy
# Processing Record 26 of Set 11 | zhezkazgan
# Processing Record 27 of Set 11 | cockburn town
# Processing Record 28 of Set 11 | burnie
# Processing Record 29 of Set 11 | bandarbeyla
# Processing Record 30 of Set 11 | anchorage
# Processing Record 31 of Set 11 | bayji
# Processing Record 32 of Set 11 | dauriya
# Processing Record 33 of Set 11 | rotifunk
# Processing Record 34 of Set 11 | linqing
# Processing Record 35 of Set 11 | saint-augustin
# Processing Record 36 of Set 11 | iwanai
# Processing Record 37 of Set 11 | moyale
# Processing Record 38 of Set 11 | willmar
# Processing Record 39 of Set 11 | aykhal
# Processing Record 40 of Set 11 | egyek
# Processing Record 41 of Set 11 | acari
# Processing Record 42 of Set 11 | bogande
# Processing Record 43 of Set 11 | sambir
# Processing Record 44 of Set 11 | pravia
# Processing Record 45 of Set 11 | horqueta
# Processing Record 46 of Set 11 | mwinilunga
# Processing Record 47 of Set 11 | grafenhainichen
# Processing Record 48 of Set 11 | pareora
# Processing Record 49 of Set 11 | husavik
# City not found. Skipping...
# Processing Record 50 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 0 of Set 12 | villeneuve-sur-lot
# Processing Record 1 of Set 12 | ko samui
# Processing Record 2 of Set 12 | gorontalo
# Processing Record 3 of Set 12 | ostrovnoy
# Processing Record 4 of Set 12 | atambua
# Processing Record 5 of Set 12 | clinton
# Processing Record 6 of Set 12 | richards bay
# Processing Record 7 of Set 12 | ternate
# Processing Record 8 of Set 12 | marechal floriano
# Processing Record 9 of Set 12 | plettenberg bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create Dataframe
citydata_df = pd.DataFrame({ 
                "City" : city_name,
                "Latitude" : latitude,
                "Longitude" : longitude,
                "Max Temp" : max_temp,
                "Humidity" : humidity,
                "Cloudiness" : cloudiness,
                "Wind Speed" : wind_speed,
                "Country" : country,
                "Date" : date
})

# %%
#show DataFrame
citydata_df
# Out:
#                             City  Latitude  Longitude  Max Temp  Humidity  \
# 0                           Asău     46.43      26.40     46.40        81
# 1                     Talcahuano    -36.72     -73.12     55.40        76
# 2                         Castro    -24.79     -50.01     59.67        94
# 3                        Mataura    -46.19     168.86     64.99        51
# 4                      Thinadhoo      0.53      72.93     82.74        76
# ..                           ...       ...        ...       ...       ...
# 565  Charter Township of Clinton     42.59     -82.92     53.60       100
# 566                 Richards Bay    -28.78      32.04     62.85        85
# 567                      Ternate      0.80     127.40     83.16        74
# 568            Marechal Floriano    -20.41     -40.68     75.20        88
# 569              Plettenberg Bay    -34.05      23.37     60.94        61
#
#      Cloudiness  Wind Speed Country        Date
# 0           100        6.93      RO  1603328317
# 1             0       13.87      CL  1603328317
# 2            19        8.55      BR  1603328317
# 3            86        4.00      NZ  1603328317
# 4            71       15.03      MV  1603328317
# ..          ...         ...     ...         ...
# 565          40        4.70      US  1603328213
# 566           2        5.93      ZA  1603328384
# 567         100        5.79      ID  1603328384
# 568          90        2.24      BR  1603328384
# 569           0        1.14      ZA  1603328385
#
# [570 rows x 9 columns]

# %%
citydata_df.to_csv(r'output_data/cities.csv', index_label='City_ID')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
citydata_df[citydata_df.Humidity > 100]
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longitude, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Latitude vs. Temperature Plot scatter plot
plt.scatter(citydata_df["Latitude"], citydata_df["Max Temp"], facecolor = "steelblue", edgecolor = "black")
#need to figure out how to set my y axis to be less than 0?
# add title
plt.title("City Latitude vs. Max Temperature (10/21/20)")

# Add x axis label
plt.xlabel("Latitude")

# Add y axis label
plt.ylabel("Max Temperature (F)")

# Add grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# The curve of the dataset is interesting. It's like a U, as you get closer to latitude 0 on either side,th max temperature drops (overall there are some outliers). The higher the latitude number the lower the Max temps, the lower the latitude number the higher the max temperature is.

# %%
#Latitude vs Humidity Plot
plt.scatter(citydata_df["Latitude"], citydata_df["Humidity"], facecolor = "steelblue", edgecolor = "black")

# add title
plt.title("City Latitude vs. Humidituy(10/21/20)")

# add x axis label
plt.xlabel("Latitude")

# add y axis label 
plt.ylabel("Humidity (%)")

# add grid lines
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# save as .pngs
plt.savefig("Images/City Latitude vs Humidity.png")

# %% [markdown]
# This shows that there are considerablly less data points in the lower latitude regions which indicates there is lower humidity in lower lower regions.  Higher humidity towards the higher latitudes.  Does this mean since there are more people in the higher latitude regions there is more humidity?  Maybe something to consider.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Latitude vs Cloudiness
plt.scatter(citydata_df["Latitude"], citydata_df["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

#add title
plt.title("City Latitude vs Cloudiness (10/21/20)")  

#add x axis label
plt.xlabel("Latitude")

#add y axis label
plt.ylabel("Cloudiness")

#add grid lines
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

#save as png
plt.savefig("Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# Theres seems to be no real correlation between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Latitude vs Wind Speed
plt.scatter(citydata_df["Latitude"], citydata_df["Wind Speed"], facecolor = "steelblue", edgecolor = "black")

#add title
plt.title("City Latitude vs Wind Speed (10/21/20)")  

#add x axis label
plt.xlabel("Latitude")

#add y axis label
plt.ylabel("Wind Speed")

#add grid lines
plt.grid(linestyle = '-', linewidth=1, alpha =0.5)

#save as png
plt.savefig("Images/City Latitude vs Wind Speed.png")

# %% [markdown]
# There seems to be consistent wind speeds around 5(mph?)speed in the higher latitudes, specifically betwen 45-75 Latitude.  There  is a consistent pattern of wind speeds =< then 10 consistently across the latitude.  I don't like this chart.

# %% [markdown]
# ## Linear Regression

# %%
#create DataFrames for the norther and souther hemispheres
N_hemisphere = citydata_df.loc[citydata_df["Latitude"] >= 0]
S_hemisphere = citydata_df.loc[citydata_df["Latitude"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#define function for linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-value is : {round(stats.pearsonr(x, y)[0],2)}")  
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

#define the fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
# Call an function #1
equation = linear_agression(N_hemisphere["Latitude"], N_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 5, 5)

# add title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# add x axis label
plt.xlabel("Latitude")

# add ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-value is : -0.89

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(S_hemisphere["Latitude"],S_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, -25, 50)

# add title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# add x axis label
plt.xlabel("Latitude")

# add y axis label
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-value is : 0.67

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(N_hemisphere["Latitude"], N_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 0, 0)

# Set title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set x axis label
plt.xlabel("Latitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-value is : 0.25

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(S_hemisphere["Latitude"], S_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# add title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# add x axis label
plt.xlabel("Latitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-value is : 0.18

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(N_hemisphere["Latitude"], N_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# add title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# add x axis label
plt.xlabel("Latitude")

# add y axis label
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-value is : 0.18

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(S_hemisphere["Latitude"], S_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# add x axis label
plt.xlabel("Latitude")

# add y axis label
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-value is : 0.02

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(N_hemisphere["Latitude"], N_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 20, 25)

# add title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# add x axis label
plt.xlabel("Latitude")

# add y axis label
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-value is : 0.09

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
equation = linear_agression(S_hemisphere["Latitude"], S_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, -25, 25)

# add title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# add x axis label
plt.xlabel("Latitude")

# add y axis label
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-value is : -0.16
