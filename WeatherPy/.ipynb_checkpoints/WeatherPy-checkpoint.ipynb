# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as stats

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Start of Data Retrieval ")
print("-----------------------------")
index_counter = 0
set_counter = 1

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
url = f"{url}appid={weather_api_key}&units={units}&q="

# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(url + city).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} | {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Start of Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | lieksa
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | yei
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 1 | egvekinot
# Processing Record 10 of Set 1 | husavik
# Processing Record 11 of Set 1 | fortuna
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | newport
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | pizarro
# Processing Record 17 of Set 1 | geraldton
# Processing Record 18 of Set 1 | kayes
# City not found. Skipping...
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | te anau
# Processing Record 21 of Set 1 | bilibino
# Processing Record 22 of Set 1 | tokur
# Processing Record 23 of Set 1 | dicabisagan
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | banepa
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | saint-joseph
# Processing Record 30 of Set 1 | brae
# Processing Record 31 of Set 1 | rocha
# Processing Record 32 of Set 1 | shaunavon
# City not found. Skipping...
# Processing Record 33 of Set 1 | longyearbyen
# Processing Record 34 of Set 1 | ovsyanka
# Processing Record 35 of Set 1 | saskylakh
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | broome
# Processing Record 41 of Set 1 | alvaraes
# Processing Record 42 of Set 1 | coquimbo
# City not found. Skipping...
# Processing Record 43 of Set 1 | tasiilaq
# Processing Record 44 of Set 1 | cherskiy
# Processing Record 45 of Set 1 | guiratinga
# Processing Record 46 of Set 1 | nueve de julio
# Processing Record 47 of Set 1 | sao joao da barra
# City not found. Skipping...
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | sumbe
# Processing Record 50 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 0 of Set 2 | charcas
# Processing Record 1 of Set 2 | touros
# Processing Record 2 of Set 2 | aswan
# Processing Record 3 of Set 2 | lompoc
# Processing Record 4 of Set 2 | ancud
# Processing Record 5 of Set 2 | sao filipe
# Processing Record 6 of Set 2 | provideniya
# Processing Record 7 of Set 2 | severo-kurilsk
# Processing Record 8 of Set 2 | mosetse
# Processing Record 9 of Set 2 | ugoofaaru
# Processing Record 10 of Set 2 | pacifica
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | somerset east
# Processing Record 13 of Set 2 | adrar
# Processing Record 14 of Set 2 | saint-francois
# Processing Record 15 of Set 2 | alofi
# City not found. Skipping...
# Processing Record 16 of Set 2 | buala
# Processing Record 17 of Set 2 | praia
# Processing Record 18 of Set 2 | alta floresta
# Processing Record 19 of Set 2 | yumen
# Processing Record 20 of Set 2 | cockburn town
# Processing Record 21 of Set 2 | sola
# Processing Record 22 of Set 2 | bima
# Processing Record 23 of Set 2 | george
# Processing Record 24 of Set 2 | yar-sale
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | cuamba
# City not found. Skipping...
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | tuatapere
# Processing Record 29 of Set 2 | kamenka
# Processing Record 30 of Set 2 | bengkulu
# City not found. Skipping...
# Processing Record 31 of Set 2 | pulaski
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | camacha
# Processing Record 35 of Set 2 | gat
# Processing Record 36 of Set 2 | mataura
# Processing Record 37 of Set 2 | blagoveshchensk
# Processing Record 38 of Set 2 | torbay
# City not found. Skipping...
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | kahului
# Processing Record 41 of Set 2 | whitehorse
# Processing Record 42 of Set 2 | chokurdakh
# Processing Record 43 of Set 2 | batemans bay
# Processing Record 44 of Set 2 | hithadhoo
# Processing Record 45 of Set 2 | pisco
# Processing Record 46 of Set 2 | hattiesburg
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | hasaki
# Processing Record 49 of Set 2 | albany
# Processing Record 50 of Set 2 | mill valley
# Processing Record 0 of Set 3 | ndele
# Processing Record 1 of Set 3 | ostrovnoy
# Processing Record 2 of Set 3 | cabedelo
# Processing Record 3 of Set 3 | arona
# Processing Record 4 of Set 3 | mount isa
# Processing Record 5 of Set 3 | kalangala
# Processing Record 6 of Set 3 | pontianak
# City not found. Skipping...
# Processing Record 7 of Set 3 | lac du bonnet
# Processing Record 8 of Set 3 | constantine
# Processing Record 9 of Set 3 | malvern
# Processing Record 10 of Set 3 | canaries
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | general roca
# Processing Record 13 of Set 3 | goderich
# Processing Record 14 of Set 3 | ouadda
# Processing Record 15 of Set 3 | awbari
# Processing Record 16 of Set 3 | nelson bay
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | vaini
# City not found. Skipping...
# Processing Record 19 of Set 3 | fuling
# Processing Record 20 of Set 3 | east london
# Processing Record 21 of Set 3 | leningradskiy
# Processing Record 22 of Set 3 | yulara
# Processing Record 23 of Set 3 | bambous virieux
# Processing Record 24 of Set 3 | narsaq
# Processing Record 25 of Set 3 | sitka
# Processing Record 26 of Set 3 | guerrero negro
# Processing Record 27 of Set 3 | chuy
# Processing Record 28 of Set 3 | qiongshan
# Processing Record 29 of Set 3 | vilyuysk
# Processing Record 30 of Set 3 | brigantine
# Processing Record 31 of Set 3 | saint george
# Processing Record 32 of Set 3 | arraial do cabo
# Processing Record 33 of Set 3 | carnduff
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | shihezi
# Processing Record 36 of Set 3 | lavrentiya
# Processing Record 37 of Set 3 | dwarka
# Processing Record 38 of Set 3 | bilhaur
# Processing Record 39 of Set 3 | mount gambier
# Processing Record 40 of Set 3 | tadine
# Processing Record 41 of Set 3 | formosa
# Processing Record 42 of Set 3 | deputatskiy
# Processing Record 43 of Set 3 | alice springs
# Processing Record 44 of Set 3 | luganville
# City not found. Skipping...
# Processing Record 45 of Set 3 | kieta
# Processing Record 46 of Set 3 | hualmay
# Processing Record 47 of Set 3 | oranjestad
# Processing Record 48 of Set 3 | la primavera
# Processing Record 49 of Set 3 | port alfred
# Processing Record 50 of Set 3 | chadiza
# Processing Record 0 of Set 4 | port angeles
# Processing Record 1 of Set 4 | san patricio
# Processing Record 2 of Set 4 | coihaique
# Processing Record 3 of Set 4 | kruisfontein
# Processing Record 4 of Set 4 | cidreira
# City not found. Skipping...
# Processing Record 5 of Set 4 | katsuura
# Processing Record 6 of Set 4 | castro
# Processing Record 7 of Set 4 | natal
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | ilulissat
# Processing Record 10 of Set 4 | darhan
# City not found. Skipping...
# Processing Record 11 of Set 4 | ajijic
# Processing Record 12 of Set 4 | saint-hyacinthe
# Processing Record 13 of Set 4 | hay river
# Processing Record 14 of Set 4 | hovd
# Processing Record 15 of Set 4 | berlevag
# Processing Record 16 of Set 4 | langsa
# Processing Record 17 of Set 4 | avarua
# Processing Record 18 of Set 4 | sahuaripa
# Processing Record 19 of Set 4 | lagoa
# Processing Record 20 of Set 4 | atambua
# Processing Record 21 of Set 4 | kamaishi
# Processing Record 22 of Set 4 | kaitangata
# Processing Record 23 of Set 4 | talnakh
# Processing Record 24 of Set 4 | airai
# Processing Record 25 of Set 4 | chabahar
# Processing Record 26 of Set 4 | pacific grove
# Processing Record 27 of Set 4 | mar del plata
# Processing Record 28 of Set 4 | srednekolymsk
# Processing Record 29 of Set 4 | aligudarz
# City not found. Skipping...
# Processing Record 30 of Set 4 | port macquarie
# Processing Record 31 of Set 4 | codrington
# Processing Record 32 of Set 4 | lumberton
# Processing Record 33 of Set 4 | westport
# Processing Record 34 of Set 4 | yuksekova
# Processing Record 35 of Set 4 | cairns
# Processing Record 36 of Set 4 | norman wells
# City not found. Skipping...
# Processing Record 37 of Set 4 | nanortalik
# Processing Record 38 of Set 4 | russell
# Processing Record 39 of Set 4 | oranjemund
# Processing Record 40 of Set 4 | saint-philippe
# Processing Record 41 of Set 4 | aklavik
# Processing Record 42 of Set 4 | vila velha
# Processing Record 43 of Set 4 | bluff
# Processing Record 44 of Set 4 | dodola
# Processing Record 45 of Set 4 | bathsheba
# City not found. Skipping...
# Processing Record 46 of Set 4 | tepelene
# Processing Record 47 of Set 4 | pangnirtung
# Processing Record 48 of Set 4 | kodiak
# Processing Record 49 of Set 4 | dingle
# Processing Record 50 of Set 4 | saint-pierre
# Processing Record 0 of Set 5 | hofn
# Processing Record 1 of Set 5 | jamestown
# Processing Record 2 of Set 5 | cabo san lucas
# Processing Record 3 of Set 5 | ambanja
# Processing Record 4 of Set 5 | monrovia
# Processing Record 5 of Set 5 | beysehir
# Processing Record 6 of Set 5 | san juan
# Processing Record 7 of Set 5 | high rock
# Processing Record 8 of Set 5 | jurm
# City not found. Skipping...
# Processing Record 9 of Set 5 | huarmey
# Processing Record 10 of Set 5 | kavaratti
# Processing Record 11 of Set 5 | buraydah
# Processing Record 12 of Set 5 | carhuaz
# Processing Record 13 of Set 5 | port keats
# Processing Record 14 of Set 5 | bethel
# Processing Record 15 of Set 5 | wiarton
# Processing Record 16 of Set 5 | surt
# Processing Record 17 of Set 5 | faanui
# Processing Record 18 of Set 5 | kenai
# Processing Record 19 of Set 5 | neiafu
# Processing Record 20 of Set 5 | ketchikan
# Processing Record 21 of Set 5 | salta
# Processing Record 22 of Set 5 | wellington
# City not found. Skipping...
# Processing Record 23 of Set 5 | vanimo
# Processing Record 24 of Set 5 | leh
# City not found. Skipping...
# Processing Record 25 of Set 5 | morros
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | dongli
# Processing Record 28 of Set 5 | yueyang
# Processing Record 29 of Set 5 | aden
# Processing Record 30 of Set 5 | khurai
# Processing Record 31 of Set 5 | iquique
# Processing Record 32 of Set 5 | panshi
# Processing Record 33 of Set 5 | sam phran
# Processing Record 34 of Set 5 | miles city
# Processing Record 35 of Set 5 | primero de enero
# Processing Record 36 of Set 5 | puerto madryn
# Processing Record 37 of Set 5 | gizo
# Processing Record 38 of Set 5 | san jeronimo
# Processing Record 39 of Set 5 | shingu
# Processing Record 40 of Set 5 | bonfim
# Processing Record 41 of Set 5 | bubaque
# Processing Record 42 of Set 5 | mahebourg
# Processing Record 43 of Set 5 | hammerfest
# Processing Record 44 of Set 5 | yeppoon
# City not found. Skipping...
# Processing Record 45 of Set 5 | bac lieu
# City not found. Skipping...
# Processing Record 46 of Set 5 | groningen
# City not found. Skipping...
# Processing Record 47 of Set 5 | sungairaya
# Processing Record 48 of Set 5 | evanston
# Processing Record 49 of Set 5 | veshenskaya
# Processing Record 50 of Set 5 | xiaoweizhai
# Processing Record 0 of Set 6 | umm kaddadah
# Processing Record 1 of Set 6 | belyy yar
# Processing Record 2 of Set 6 | beboto
# Processing Record 3 of Set 6 | sechura
# Processing Record 4 of Set 6 | isla vista
# Processing Record 5 of Set 6 | jizan
# Processing Record 6 of Set 6 | zhezkazgan
# Processing Record 7 of Set 6 | hemsedal
# Processing Record 8 of Set 6 | haputale
# Processing Record 9 of Set 6 | krasnyy chikoy
# Processing Record 10 of Set 6 | uvat
# Processing Record 11 of Set 6 | cedar city
# Processing Record 12 of Set 6 | marawi
# Processing Record 13 of Set 6 | elkhart
# City not found. Skipping...
# Processing Record 14 of Set 6 | campobello di mazara
# Processing Record 15 of Set 6 | lakselv
# Processing Record 16 of Set 6 | luderitz
# Processing Record 17 of Set 6 | dhidhdhoo
# Processing Record 18 of Set 6 | antalaha
# Processing Record 19 of Set 6 | esperance
# City not found. Skipping...
# Processing Record 20 of Set 6 | kungurtug
# Processing Record 21 of Set 6 | abashiri
# Processing Record 22 of Set 6 | pevek
# Processing Record 23 of Set 6 | taoudenni
# Processing Record 24 of Set 6 | rio gallegos
# Processing Record 25 of Set 6 | porto belo
# Processing Record 26 of Set 6 | biga
# Processing Record 27 of Set 6 | saiha
# Processing Record 28 of Set 6 | itoman
# Processing Record 29 of Set 6 | kharp
# Processing Record 30 of Set 6 | broken hill
# Processing Record 31 of Set 6 | pudozh
# Processing Record 32 of Set 6 | ariquemes
# Processing Record 33 of Set 6 | north platte
# Processing Record 34 of Set 6 | byron bay
# Processing Record 35 of Set 6 | livingstone
# Processing Record 36 of Set 6 | natalio
# Processing Record 37 of Set 6 | meulaboh
# Processing Record 38 of Set 6 | lebu
# City not found. Skipping...
# Processing Record 39 of Set 6 | rumonge
# Processing Record 40 of Set 6 | ponta delgada
# Processing Record 41 of Set 6 | naze
# City not found. Skipping...
# Processing Record 42 of Set 6 | hirara
# Processing Record 43 of Set 6 | kapit
# Processing Record 44 of Set 6 | sarkand
# Processing Record 45 of Set 6 | diffa
# Processing Record 46 of Set 6 | pahrump
# Processing Record 47 of Set 6 | anori
# Processing Record 48 of Set 6 | barranca
# Processing Record 49 of Set 6 | hailar
# Processing Record 50 of Set 6 | bocas del toro
# Processing Record 0 of Set 7 | masterton
# Processing Record 1 of Set 7 | half moon bay
# City not found. Skipping...
# Processing Record 2 of Set 7 | urusha
# Processing Record 3 of Set 7 | tual
# Processing Record 4 of Set 7 | nouadhibou
# Processing Record 5 of Set 7 | modasa
# Processing Record 6 of Set 7 | san quintin
# Processing Record 7 of Set 7 | wajima
# Processing Record 8 of Set 7 | panama city
# Processing Record 9 of Set 7 | san policarpo
# Processing Record 10 of Set 7 | kailua
# Processing Record 11 of Set 7 | jammalamadugu
# Processing Record 12 of Set 7 | sorland
# Processing Record 13 of Set 7 | ribeira brava
# Processing Record 14 of Set 7 | brooks
# Processing Record 15 of Set 7 | morehead
# City not found. Skipping...
# Processing Record 16 of Set 7 | dzerzhinsk
# Processing Record 17 of Set 7 | ampanihy
# Processing Record 18 of Set 7 | iracoubo
# City not found. Skipping...
# Processing Record 19 of Set 7 | bambanglipuro
# Processing Record 20 of Set 7 | dzhebariki-khaya
# Processing Record 21 of Set 7 | morondava
# Processing Record 22 of Set 7 | mantua
# Processing Record 23 of Set 7 | vadso
# Processing Record 24 of Set 7 | southbridge
# Processing Record 25 of Set 7 | fairbanks
# Processing Record 26 of Set 7 | manado
# Processing Record 27 of Set 7 | ixtapa
# Processing Record 28 of Set 7 | bowen
# Processing Record 29 of Set 7 | thompson
# Processing Record 30 of Set 7 | svetlogorsk
# Processing Record 31 of Set 7 | hayden
# City not found. Skipping...
# Processing Record 32 of Set 7 | dakar
# Processing Record 33 of Set 7 | asau
# Processing Record 34 of Set 7 | larsnes
# Processing Record 35 of Set 7 | college
# Processing Record 36 of Set 7 | namatanai
# Processing Record 37 of Set 7 | anadyr
# Processing Record 38 of Set 7 | puerto quijarro
# Processing Record 39 of Set 7 | isangel
# Processing Record 40 of Set 7 | sabang
# Processing Record 41 of Set 7 | bulgan
# Processing Record 42 of Set 7 | akureyri
# Processing Record 43 of Set 7 | portland
# Processing Record 44 of Set 7 | onzaga
# Processing Record 45 of Set 7 | bukachacha
# Processing Record 46 of Set 7 | ulcinj
# City not found. Skipping...
# Processing Record 47 of Set 7 | flinders
# Processing Record 48 of Set 7 | salalah
# Processing Record 49 of Set 7 | krasnogorskoye
# Processing Record 50 of Set 7 | waipawa
# Processing Record 0 of Set 8 | yalta
# Processing Record 1 of Set 8 | port hardy
# Processing Record 2 of Set 8 | sioux lookout
# Processing Record 3 of Set 8 | lalganj
# City not found. Skipping...
# Processing Record 4 of Set 8 | andenes
# Processing Record 5 of Set 8 | bredy
# City not found. Skipping...
# Processing Record 6 of Set 8 | dembi dolo
# Processing Record 7 of Set 8 | henties bay
# Processing Record 8 of Set 8 | atlantic city
# City not found. Skipping...
# Processing Record 9 of Set 8 | pathalgaon
# Processing Record 10 of Set 8 | libreville
# Processing Record 11 of Set 8 | rudsar
# Processing Record 12 of Set 8 | seguela
# Processing Record 13 of Set 8 | zhigansk
# Processing Record 14 of Set 8 | baykit
# Processing Record 15 of Set 8 | cap-haitien
# Processing Record 16 of Set 8 | paonta sahib
# Processing Record 17 of Set 8 | bacolod
# Processing Record 18 of Set 8 | port lincoln
# Processing Record 19 of Set 8 | suamico
# City not found. Skipping...
# Processing Record 20 of Set 8 | mongo
# Processing Record 21 of Set 8 | lingdong
# Processing Record 22 of Set 8 | aitape
# Processing Record 23 of Set 8 | blackwater
# Processing Record 24 of Set 8 | velizh
# Processing Record 25 of Set 8 | los llanos de aridane
# City not found. Skipping...
# Processing Record 26 of Set 8 | timizart
# Processing Record 27 of Set 8 | cifuentes
# Processing Record 28 of Set 8 | longhua
# Processing Record 29 of Set 8 | fuerte olimpo
# Processing Record 30 of Set 8 | svobodnyy
# Processing Record 31 of Set 8 | kabalo
# Processing Record 32 of Set 8 | margate
# Processing Record 33 of Set 8 | shache
# Processing Record 34 of Set 8 | kysyl-syr
# Processing Record 35 of Set 8 | hami
# Processing Record 36 of Set 8 | bonthe
# Processing Record 37 of Set 8 | boden
# Processing Record 38 of Set 8 | ucluelet
# Processing Record 39 of Set 8 | chara
# Processing Record 40 of Set 8 | neftcala
# Processing Record 41 of Set 8 | somerville
# Processing Record 42 of Set 8 | marsh harbour
# Processing Record 43 of Set 8 | nanakuli
# Processing Record 44 of Set 8 | oakdale
# Processing Record 45 of Set 8 | north bend
# City not found. Skipping...
# Processing Record 46 of Set 8 | fort nelson
# Processing Record 47 of Set 8 | lulea
# Processing Record 48 of Set 8 | komsomolskiy
# Processing Record 49 of Set 8 | pau brasil
# Processing Record 50 of Set 8 | atar
# Processing Record 0 of Set 9 | camana
# Processing Record 1 of Set 9 | severo-yeniseyskiy
# Processing Record 2 of Set 9 | santos reyes nopala
# Processing Record 3 of Set 9 | san cristobal
# Processing Record 4 of Set 9 | huilong
# Processing Record 5 of Set 9 | mogadishu
# Processing Record 6 of Set 9 | jacmel
# Processing Record 7 of Set 9 | nukus
# Processing Record 8 of Set 9 | superior
# Processing Record 9 of Set 9 | grand gaube
# City not found. Skipping...
# Processing Record 10 of Set 9 | anchorage
# Processing Record 11 of Set 9 | gladstone
# Processing Record 12 of Set 9 | comodoro rivadavia
# Processing Record 13 of Set 9 | zhicheng
# Processing Record 14 of Set 9 | fukuma
# Processing Record 15 of Set 9 | sokolka
# City not found. Skipping...
# Processing Record 16 of Set 9 | bilma
# City not found. Skipping...
# Processing Record 17 of Set 9 | gimbi
# Processing Record 18 of Set 9 | vila franca do campo
# Processing Record 19 of Set 9 | dudinka
# Processing Record 20 of Set 9 | lima
# Processing Record 21 of Set 9 | lorengau
# Processing Record 22 of Set 9 | lengshuitan
# Processing Record 23 of Set 9 | barrhead
# Processing Record 24 of Set 9 | bukama
# Processing Record 25 of Set 9 | harbour breton
# Processing Record 26 of Set 9 | mehamn
# Processing Record 27 of Set 9 | nome
# Processing Record 28 of Set 9 | hamilton
# Processing Record 29 of Set 9 | piterka
# City not found. Skipping...
# Processing Record 30 of Set 9 | abonnema
# Processing Record 31 of Set 9 | saint anthony
# Processing Record 32 of Set 9 | constitucion
# Processing Record 33 of Set 9 | agadez
# Processing Record 34 of Set 9 | buffalo
# Processing Record 35 of Set 9 | stari bohorodchany
# Processing Record 36 of Set 9 | jibuti
# Processing Record 37 of Set 9 | severodvinsk
# Processing Record 38 of Set 9 | neuquen
# Processing Record 39 of Set 9 | melfort
# Processing Record 40 of Set 9 | roald
# Processing Record 41 of Set 9 | paveh
# Processing Record 42 of Set 9 | barra do garcas
# Processing Record 43 of Set 9 | lakatoro
# Processing Record 44 of Set 9 | sretensk
# Processing Record 45 of Set 9 | bemidji
# Processing Record 46 of Set 9 | vestmannaeyjar
# Processing Record 47 of Set 9 | tahe
# Processing Record 48 of Set 9 | clyde river
# Processing Record 49 of Set 9 | rabo de peixe
# Processing Record 50 of Set 9 | vesoul
# Processing Record 0 of Set 10 | villa del rosario
# Processing Record 1 of Set 10 | lyuban
# City not found. Skipping...
# Processing Record 2 of Set 10 | kaeo
# Processing Record 3 of Set 10 | lubyany
# Processing Record 4 of Set 10 | grindavik
# City not found. Skipping...
# Processing Record 5 of Set 10 | kichera
# City not found. Skipping...
# Processing Record 6 of Set 10 | grinnell
# City not found. Skipping...
# Processing Record 7 of Set 10 | nemuro
# Processing Record 8 of Set 10 | puerto del rosario
# Processing Record 9 of Set 10 | bani walid
# Processing Record 10 of Set 10 | bodden town
# Processing Record 11 of Set 10 | katangli
# Processing Record 12 of Set 10 | port augusta
# Processing Record 13 of Set 10 | hambantota
# Processing Record 14 of Set 10 | aasiaat
# Processing Record 15 of Set 10 | senneterre
# Processing Record 16 of Set 10 | tabou
# Processing Record 17 of Set 10 | saint andrews
# Processing Record 18 of Set 10 | pulsano
# Processing Record 19 of Set 10 | mazyr
# Processing Record 20 of Set 10 | banjar
# Processing Record 21 of Set 10 | kostyantynivka
# Processing Record 22 of Set 10 | talcahuano
# Processing Record 23 of Set 10 | griffith
# Processing Record 24 of Set 10 | uvinza
# Processing Record 25 of Set 10 | la romana
# Processing Record 26 of Set 10 | ekhabi
# Processing Record 27 of Set 10 | araouane
# Processing Record 28 of Set 10 | birjand
# Processing Record 29 of Set 10 | houston
# Processing Record 30 of Set 10 | upata
# Processing Record 31 of Set 10 | suratgarh
# Processing Record 32 of Set 10 | nyurba
# Processing Record 33 of Set 10 | alcazar de san juan
# Processing Record 34 of Set 10 | paamiut
# Processing Record 35 of Set 10 | sur
# Processing Record 36 of Set 10 | chicama
# Processing Record 37 of Set 10 | eydhafushi
# Processing Record 38 of Set 10 | palmas
# Processing Record 39 of Set 10 | saryagash
# Processing Record 40 of Set 10 | qinggang
# Processing Record 41 of Set 10 | renqiu
# Processing Record 42 of Set 10 | nuuk
# Processing Record 43 of Set 10 | south valley
# Processing Record 44 of Set 10 | richards bay
# Processing Record 45 of Set 10 | amahai
# Processing Record 46 of Set 10 | mwene-ditu
# Processing Record 47 of Set 10 | atherton
# Processing Record 48 of Set 10 | rosario do sul
# Processing Record 49 of Set 10 | jaworzno
# Processing Record 50 of Set 10 | yanliang
# Processing Record 0 of Set 11 | neyshabur
# Processing Record 1 of Set 11 | tazovskiy
# Processing Record 2 of Set 11 | la crosse
# Processing Record 3 of Set 11 | balkanabat
# Processing Record 4 of Set 11 | eureka
# City not found. Skipping...
# Processing Record 5 of Set 11 | la ronge
# Processing Record 6 of Set 11 | kawardha
# Processing Record 7 of Set 11 | abu samrah
# Processing Record 8 of Set 11 | lahij
# Processing Record 9 of Set 11 | namestovo
# Processing Record 10 of Set 11 | stende
# Processing Record 11 of Set 11 | ossora
# Processing Record 12 of Set 11 | clinton
# Processing Record 13 of Set 11 | khoy
# Processing Record 14 of Set 11 | pokrovsk
# Processing Record 15 of Set 11 | avera
# Processing Record 16 of Set 11 | sikasso
# Processing Record 17 of Set 11 | bud
# Processing Record 18 of Set 11 | samarai
# Processing Record 19 of Set 11 | svetlyy
# Processing Record 20 of Set 11 | zarubino
# Processing Record 21 of Set 11 | eslov
# Processing Record 22 of Set 11 | saint simons
# City not found. Skipping...
# Processing Record 23 of Set 11 | la quinta
# Processing Record 24 of Set 11 | havre-saint-pierre
# Processing Record 25 of Set 11 | poum
# Processing Record 26 of Set 11 | dunedin
# Processing Record 27 of Set 11 | ha tinh
# Processing Record 28 of Set 11 | tarrafal
# Processing Record 29 of Set 11 | abu dhabi
# Processing Record 30 of Set 11 | lodwar
# Processing Record 31 of Set 11 | padang
# Processing Record 32 of Set 11 | tombouctou
# Processing Record 33 of Set 11 | rundu
# Processing Record 34 of Set 11 | torbat-e jam
# Processing Record 35 of Set 11 | mataram
# Processing Record 36 of Set 11 | valparaiso
# Processing Record 37 of Set 11 | mvuma
# City not found. Skipping...
# Processing Record 38 of Set 11 | uyemskiy
# Processing Record 39 of Set 11 | bialystok
# Processing Record 40 of Set 11 | fort frances
# Processing Record 41 of Set 11 | aksha
# Processing Record 42 of Set 11 | sirjan
# Processing Record 43 of Set 11 | kodaikanal
# Processing Record 44 of Set 11 | malartic
# Processing Record 45 of Set 11 | qeshm
# Processing Record 46 of Set 11 | tena
# Processing Record 47 of Set 11 | maryville
# Processing Record 48 of Set 11 | sinop
# Processing Record 49 of Set 11 | feijo
# Processing Record 50 of Set 11 | harper
# Processing Record 0 of Set 12 | pareora
# Processing Record 1 of Set 12 | porbandar
# Processing Record 2 of Set 12 | gigmoto
# Processing Record 3 of Set 12 | ndola
# Processing Record 4 of Set 12 | daru
# Processing Record 5 of Set 12 | bintulu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create Dataframe
citydata_df = pd.DataFrame({ 
                "City" : city_name,
                "Latitude" : latitude,
                "Longitude" : longitude,
                "Max Temp" : max_temp,
                "Humidity" : humidity,
                "Cloudiness" : cloudiness,
                "Wind Speed" : wind_speed,
                "Country" : country,
                "Date" : date
})

# %%
#show DataFrame
citydata_df
# Out:
#              City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0           Kapaa     22.08    -159.32     80.60        74          20
# 1     New Norfolk    -42.78     147.06     50.00        85          93
# 2          Lieksa     63.32      30.02     32.83        96         100
# 3         Ushuaia    -54.80     -68.30     55.40        43          75
# 4    Punta Arenas    -53.15     -70.92     48.20        49          90
# ..            ...       ...        ...       ...       ...         ...
# 561     Porbandar     21.64      69.61     82.08        77           3
# 562       Gigmoto     13.78     124.39     81.16        82          98
# 563         Ndola    -12.96      28.64     72.00        36          22
# 564          Daru     -9.08     143.21     78.01        85          19
# 565       Bintulu      3.17     113.03     75.20        94          20
#
#      Wind Speed Country        Date
# 0          5.82      US  1603311817
# 1          2.26      AU  1603311807
# 2         14.14      FI  1603312186
# 3          5.82      AR  1603311680
# 4          6.93      CL  1603311807
# ..          ...     ...         ...
# 561       10.78      IN  1603312260
# 562       11.97      PH  1603311821
# 563        6.38      ZM  1603312260
# 564        9.24      PG  1603312260
# 565        6.93      MY  1603312260
#
# [566 rows x 9 columns]

# %%
citydata_df.to_csv(r'output_data/cities.csv', index_label='City_ID')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# check for cities that have humidity >100%

# define column names for the new dataframe
column_names = ["City", "Cloudiness", "Date", "Humidity", "Longitude", "Country", "Latitude", "Max Temp", "Wind Speed"]
newcitydata_df = pd.DataFrame(columns = column_names)
# cycle through the city data to find humidity over 100%
x = 0
for x in range(len(citydata_df)):
   if (citydata_df.iloc[x]['Humidity'] > 100):
       print('Citi_ID with > 100% humidity =',x)
   else:
       newcitydata_df.loc[citydata_df.index[x]] = citydata_df.iloc[x] #copy good data into new DF
newcitydata_df.reset_index(drop=True, inplace=True)
newcitydata_df
# Out:
#              City Cloudiness        Date Humidity  Longitude Country  \
# 0           Kapaa         20  1603311817       74    -159.32      US
# 1     New Norfolk         93  1603311807       85     147.06      AU
# 2          Lieksa        100  1603312186       96      30.02      FI
# 3         Ushuaia         75  1603311680       43     -68.30      AR
# 4    Punta Arenas         90  1603311807       49     -70.92      CL
# ..            ...        ...         ...      ...        ...     ...
# 561     Porbandar          3  1603312260       77      69.61      IN
# 562       Gigmoto         98  1603311821       82     124.39      PH
# 563         Ndola         22  1603312260       36      28.64      ZM
# 564          Daru         19  1603312260       85     143.21      PG
# 565       Bintulu         20  1603312260       94     113.03      MY
#
#      Latitude  Max Temp  Wind Speed
# 0       22.08     80.60        5.82
# 1      -42.78     50.00        2.26
# 2       63.32     32.83       14.14
# 3      -54.80     55.40        5.82
# 4      -53.15     48.20        6.93
# ..        ...       ...         ...
# 561     21.64     82.08       10.78
# 562     13.78     81.16       11.97
# 563    -12.96     72.00        6.38
# 564     -9.08     78.01        9.24
# 565      3.17     75.20        6.93
#
# [566 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Latitude vs. Temperature Plot scatter plot
plt.scatter(newcitydata_df["Latitude"], newcitydata_df["Max Temp"], facecolor = "steelblue", edgecolor = "black")
#need to figure out how to set my y axis to be less than 0?
#title
plt.title("City Latitude vs. Max Temperature (10/21/20)")

# Add x axis label
plt.xlabel("Latitude")

# Add y axis label
plt.ylabel("Max Temperature (F)")

# Add grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# The curve of the dataset is interesting. It's like a U, as you get closer to latitude 0 on either side,th max temperature drops (overall there are some outliers). The higher the latitude number the lower the Max temps, the lower the latitude number the higher the max temperature is.

# %%
#Latitude vs Humidity Plot
plt.scatter(newcitydata_df["Latitude"], newcitydata_df["Humidity"], facecolor = "steelblue", edgecolor = "black")

#title
plt.title("City Latitude vs. Humidituy(10/21/20)")

# add x axis label
plt.xlabel("Latitude")

# add y axis label 
plt.ylabel("Humidity (%)")

# add grid lines
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# save as .pngs
plt.savefig("Images/City Latitude vs Humidity.png")

# %% [markdown]
# This shows that there are considerablly less data points in the lower latitude regions which indicates there is lower humidity in lower lower regions.  Higher humidity towards the higher latitudes.  Does this mean since there are more people in the higher latitude regions there is more humidity?  Maybe something to consider.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Latitude vs Cloudiness
plt.scatter(newcitydata_df["Latitude"], newcitydata_df["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

#title
plt.title("City Latitude vs Cloudiness (10/21/20)")  

#add x axis label
plt.xlabel("Latitude")

#add y axis label
plt.ylabel("Cloudiness")

#add grid lines
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

#save as png
plt.savefig("Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# Theres seems to be no real deliniation to me that there is a correlation between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Latitude vs Wind Speed
plt.scatter(newcitydata_df["Latitude"], newcitydata_df["Wind Speed"], facecolor = "steelblue", edgecolor = "black")

#title
plt.title("City Latitude vs Wind Speed (10/21/20)")  

#add x axis label
plt.xlabel("Latitude")

#add y axis label
plt.ylabel("Wind Speed")

#add grid lines
plt.grid(linestyle = '-', linewidth=1, alpha =0.5)

#save as png
plt.savefig("Images/City Latitude vs Wind Speed.png")

# %% [markdown]
# There seems to be consistent wind speeds around 5(mph?)speed in the higher latitudes, specifically betwen 45-75 Latitude.  There  is a consistent pattern of wind speeds =< then 10 consistently across the latitude.  I don't like this chart.

# %% [markdown]
# ## Linear Regression

# %%
#create DataFrames for the norther and souther hemispheres
N_hemisphere = newcitydata_df.loc[citydata_df["Latitude"] >= 0]
S_hemisphere = newcitydata_df.loc[citydata_df["Latitude"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#I found this here https://towardsdatascience.com/linear-regression-in-6-lines-of-python-5e1d0cd05b8d  
# To use this I have to figure out the location the data right?

#Perform linear regression
#x = N_hemisphere.iloc[:, 0].values.reshap(-1, 1)#I am not sure how to get this to work? 
#y = S_hemisphere.iloc[:, 1].values.reshap(-1,1)
#lr = LinearRegression()
#lr.fit(X,Y)
#Y_pred = lr.predict(X)

# %%
#visualize results
#plt.scatter(X,Y)
#plt.plot(X,Y_pred, color= "red")
#plt.show()

# %%
#get function for linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(stats.pearsonr(x, y)[0],2)}") #error here!  
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
# Call an function #1
equation = linear_agression(N_hemisphere["Latitude"], N_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 0, 0)

# add a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# add xlabel
plt.xlabel("Latitude")

# add ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.85

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(S_hemisphere["Latitude"],S_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# add a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# add xlabel
plt.xlabel("Latitude")

# add ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.73

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
